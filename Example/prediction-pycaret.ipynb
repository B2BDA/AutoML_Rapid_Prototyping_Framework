# %%
import orchest
# Retrieve the data from the previous step.
data = orchest.get_inputs()
test = data["test_data"]

# %%
# Importing module and initializing setup
from pycaret.classification import *
# Loading the saved model
xgboost = load_model('xgboost')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
# generate predictions on unseen data
predictions = predict_model(xgboost, data = test)

# %%
predictions.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 262316  160417.0 -1.651422 -0.629338  0.918720 -2.886850 -0.970557 -0.132473
# 160335  113258.0 -1.290991 -0.445060 -0.445495  0.232973  1.817626 -0.593481
# 134134   80660.0 -0.882201  0.711943  1.336114  0.292672  1.024640  1.176690
# 37168    38833.0 -1.385148  0.822839  1.947569  0.530189 -0.915822  0.701242
# 81682    59045.0 -0.360079  0.914427  0.936358 -0.403613  0.738064  0.361976
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 262316 -0.133056  0.291170 -2.305110  0.340218 -1.118431 -0.364267  1.795893
# 160335  0.427890  0.010332 -0.278319 -0.287420  0.702552 -0.118260 -0.849669
# 134134  0.478149  0.432917 -0.505282 -0.524786  0.295444 -0.019392 -0.538933
# 37168  -0.684553  0.757460  0.148048 -0.112411  0.863070  0.514966 -0.848299
# 81682   0.563440  0.195118 -0.213317 -0.338049 -1.531732 -0.745187 -0.341951
#
#              V14       V15       V16       V17       V18       V19       V20  \
# 262316 -0.716768 -0.679517 -0.169243  0.306654 -0.069292 -0.852386 -0.218867
# 160335 -0.575792 -0.061498  0.136004  0.501703  0.611671  1.456462 -0.217322
# 134134  0.441158  1.892515 -1.320073  0.798777 -1.723947 -1.783790 -0.233787
# 37168   0.123943  0.207442 -0.294686  0.441395  0.197115  1.105896 -0.204848
# 81682   0.205806  1.268023  0.342516 -0.589450 -0.270715  0.186496  0.075559
#
#              V21       V22       V23       V24       V25       V26       V27  \
# 262316 -0.141590 -0.064385 -0.390010  0.710111  0.701797 -0.162619  0.182455
# 160335 -0.259508 -0.469767  1.020539  0.167930 -0.805144  0.241578 -0.094280
# 134134  0.365750  1.147685 -0.183656 -0.950050 -0.101986 -0.148459  0.049220
# 37168   0.150901  0.325293 -0.004974  0.057066 -0.450473  0.512862 -0.530251
# 81682  -0.298339 -0.787065 -0.154512 -1.364120 -0.099751  0.189661  0.275492
#
#              V28  Amount  Class  Label   Score
# 262316 -0.126199  158.00      0      0  0.5891
# 160335  0.425813    1.29      0      0  0.5606
# 134134  0.121186   24.67      0      0  0.5908
# 37168   0.055289   12.00      0      0  0.5926
# 81682   0.102209    4.49      0      0  0.5788

# %%
orchest.output(predictions, name="predicted_data")
