# %%
import orchest
# Retrieve the data from the previous step.
data = orchest.get_inputs()
train, test = data["clean_data"]

# %%
# Get the parameters of the current step and the pipeline.
silent = bool(orchest.get_step_param("silent"))
profile = bool(orchest.get_step_param("profile")) 
fix_imbalance = bool(orchest.get_step_param("fix_imbalance"))

# %%
from pycaret.classification import *
clf1 = setup(data = train, target = 'Class', silent = silent,profile = profile, fix_imbalance = fix_imbalance )

# %%
# return best model
best = compare_models()

# %%
best

# %%
# create model + training
xgboost = create_model('xgboost')

# %%
# hyperparameter tuning
xgboost = tune_model(xgboost, optimize = 'AUC')

# %%
# plotting a model
plot_model(xgboost)

# %%
xgboost = finalize_model(xgboost)

# %%
# save a model
save_model(xgboost, 'xgboost')

# %%
orchest.output(test, name="test_data")
